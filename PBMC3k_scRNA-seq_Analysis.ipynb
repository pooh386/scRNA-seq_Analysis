# %%
import scanpy as sc
print(sc.__version__)
# Out:
# 1.11.5
# C:\Users\JUHWANKIM\AppData\Local\Temp\ipykernel_15508\289967954.py:2: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('scanpy')` instead
#   print(sc.__version__)

# %%
import scanpy as sc
import pandas as pd
import numpy as np

adata = sc.datasets.pbmc3k()
adata
# Out:
# AnnData object with n_obs × n_vars = 2700 × 32738
#     var: 'gene_ids'

# %%
sc.pp.filter_genes(adata, min_cells=3)

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
adata.raw = adata

# %%
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5, flavor='cell_ranger')
sc.pl.highly_variable_genes(adata)

# %%
sc.tl.pca(adata, svd_solver='arpack')
sc.pl.pca(adata)

# %%
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=40)
sc.tl.umap(adata)
sc.pl.umap(adata)

# %%
sc.tl.leiden(adata, flavor='igraph', n_iterations=2)
sc.pl.umap(adata, color='leiden')

# %%
sc.tl.rank_genes_groups(adata, 'leiden', method='t-test')

# %%
sc.pl.rank_genes_groups_dotplot(adata, n_genes=5)
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_leiden). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.

# %%
sc.pl.umap(adata, color=['CST3', 'NKG7', 'MS4A1'])
